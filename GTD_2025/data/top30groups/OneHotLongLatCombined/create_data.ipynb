# %%
import pandas as pd
import numpy as np
import os

# %%
def oneHotEncode(traindata, testdata):
    train_features = traindata.drop(columns='gname')
    test_features = testdata.drop(columns=['gname'])

    #One hot Encoding
    geodata = ['longitude','latitude']
    all_categories = pd.concat([train_features, test_features])
    onehot = pd.get_dummies(all_categories, columns=geodata)

    train_features = onehot.iloc[:len(train_features)]
    test_features = onehot.iloc[len(train_features):]

    traindata = pd.concat([train_features, traindata['gname']], axis=1)
    testdata = pd.concat([test_features, testdata['gname']], axis=1)

    return traindata, testdata

# %%
if not os.path.isdir("train"):
    os.mkdir("train")
if not os.path.isdir("test"):
    os.mkdir("test")

# %%
trainpath = '../traindata'
testpath = '../testdata'

partitions = [100, 200, 300, 478]

for partition in partitions:
    traindata = pd.read_csv(f'{trainpath}/train{partition}.csv',  encoding='ISO-8859-1')
    testdata = pd.read_csv(f'{testpath}/test{partition}.csv',  encoding='ISO-8859-1')

    traindata = traindata.drop(columns=['Unnamed: 0', 'country', 'city', 'region', 'provstate', 'natlty1', 'specificity', 'iyear', 'imonth', 'iday'])
    testdata = testdata.drop(columns=['Unnamed: 0', 'country', 'city', 'region', 'provstate', 'natlty1', 'specificity', 'iyear', 'imonth', 'iday'])

    traindata, testdata = oneHotEncode(traindata, testdata)
    num_numeric_cols = traindata.select_dtypes(include='number').shape[1]

    print("Number of numeric columns:", num_numeric_cols)
    print(f'Size train: {len(traindata)}, Shape train: {traindata.shape}')
    print(f'Size test: {len(testdata)}, Shape test: {testdata.shape}')
    
    traindata.to_csv(f'train/train{partition}.csv')
    traindata.to_csv(f'test/test{partition}.csv')
# Out:
# Number of numeric columns: 13
# Size train: 2100, Shape train: (2100, 3583)
# Size test: 900, Shape test: (900, 3583)
# Number of numeric columns: 13
# Size train: 4200, Shape train: (4200, 6306)
# Size test: 1800, Shape test: (1800, 6306)
# Number of numeric columns: 13
# Size train: 6300, Shape train: (6300, 8725)
# Size test: 2700, Shape test: (2700, 8725)
# Number of numeric columns: 13
# Size train: 10020, Shape train: (10020, 12512)
# Size test: 4320, Shape test: (4320, 12512)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 21
#      18 print(f'Size test: {len(testdata)}, Shape test: {testdata.shape}')
#      20 traindata.to_csv(f'train/train{partition}.csv')
# ---> 21 traindata.to_csv(f'test/test{partition}.csv')
#
# ...
