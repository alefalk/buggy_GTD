# %%
import warnings
warnings.filterwarnings( 'ignore' )
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from RF_predictions import *

# %% [markdown]
# ### Paths to top30 from GTD data

# %%
partitions = ['df_top30_100', 'df_top30_200', 'df_top30_300', 'df_top30_478']
dir = '../../../data/top30groups'

paths = []
for i, partition in enumerate(partitions):
    paths.append(f'{dir}/{partition}.csv')

print(paths)
# Out:
# ['../../../data/top30groups/df_top30_100.csv', '../../../data/top30groups/df_top30_200.csv', '../../../data/top30groups/df_top30_300.csv', '../../../data/top30groups/df_top30_478.csv']

# %% [markdown]
# ### Training models and computing accuracy

# %%
models = []
accuracies = []
n = [100, 200, 300, 478]
for i, path in enumerate(paths):
    print(f'Computing for partition {partitions[i]}, balanced classes with {n[i]} entries for each class')
    model, accuracy, y_pred_xgb, labels = main(path)
    models.append(model)
    print("---------------------------------------------------")
# Out:
# Computing for partition df_top30_100, balanced classes with 100 entries for each class
# 2100
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 93.56%
# ---------------------------------------------------
# Computing for partition df_top30_200, balanced classes with 200 entries for each class
# 4200
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 89.39%
# ---------------------------------------------------
# Computing for partition df_top30_300, balanced classes with 300 entries for each class
# 6300
# Finding optimal hyperparameters...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Training best RF classifier...
# Making predictions...
# Accuracy: 88.48%
# ---------------------------------------------------
# ...

# %%
print(classification_report(labels, y_pred_xgb))
# Out:
#                                                   precision    recall  f1-score   support
#
#                           Abu Sayyaf Group (ASG)       1.00      1.00      1.00       144
#         African National Congress (South Africa)       1.00      0.99      1.00       144
#                                 Al-Qaida in Iraq       1.00      0.62      0.76       144
#         Al-Qaida in the Arabian Peninsula (AQAP)       1.00      0.22      0.36       144
#                                       Al-Shabaab       1.00      1.00      1.00       144
#              Basque Fatherland and Freedom (ETA)       0.99      0.99      0.99       144
#                                       Boko Haram       0.97      1.00      0.99       144
#   Communist Party of India - Maoist (CPI-Maoist)       1.00      0.12      0.21       144
#        Corsican National Liberation Front (FLNC)       0.99      1.00      0.99       144
# ...
